# %% [markdown]
# <a href="https://colab.research.google.com/github/RFeld1/python-data-analysis/blob/master/adp_atividade01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![header.png](data:image/png;base64,...)

# %% [markdown]
# # Análise de Dados em Python
# **Professor Responsável:** Antonio Sergio Ferreira Bonato <antonio.bonato@saojudas.br>

# %% [markdown]
# **Nome:** Raphael Feldberg Ramos

# %% [markdown]
# # Atividade01 - Pyton Básico
#
# **Conteúdo:**
# - Introdução ao Python
# - Anaconda e Jupyter Notebook
# - Números
# - Strings
# - Formatação de Strings
# - Listas
# - Dicionários
# - Tuplas
# - Sets
# - Booleans
# - Arquivos

# %% [markdown]
# ## Exercícios

# %% [markdown]
# #### 1 Faça um Programa que peça o raio de um círculo, calcule e mostre sua área.

# %%
#solução

# %% [markdown]
# #### 2 Faça um Programa que peça a temperatura em graus Farenheit, transforme e mostre a temperatura em graus Celsius. C = (5 * (F-32) / 9).

# %%
#solução

# %% [markdown]
# #### 3 Faça um Programa que peça 2 números inteiros e um número real. Calcule e mostre:
# - o produto do dobro do primeiro com metade do segundo .
# - a soma do triplo do primeiro com o terceiro.
# - o terceiro elevado ao cubo.

# %%
#solução

# %% [markdown]
# #### 4 Faça um programa que permita ao usuário digitar seu nome e em seguida mostre o nome do usuário de trás para frente utilizando somente letras maiúsculas. Observação: não use loops.

# %%
#solução

# %% [markdown]
# #### 5 Peça para o usuário digitar uma frase. Escreva esta frase iniciando todas as palavras com letra maiúscula. Não use loops.

# %%
#solução

# %% [markdown]
# #### 6 Faça um programa que receba duas listas e retorne True se são iguais ou False caso contrario. Duas listas são iguais se possuem os mesmos valores e na mesma ordem.

# %%
#solução

# %% [markdown]
# #### 7 Faça um programa que percorre uma lista com o seguinte formato:
# `[['Brasil', 'Italia', [10, 9]], ['Brasil', 'Espanha', [5, 7]], ['Italia', 'Espanha', [7,8]]]`.
# <br>
# <br> Essa lista indica o número de faltas que cada time fez em cada jogo. Na lista acima, no jogo entre Brasil e Itália, o Brasil fez 10 faltas e a Itália fez 9.
# <br>O programa deve imprimir na tela:
# - o total de faltas do campeonato
# - o time que fez mais faltas
# - o time que fez menos faltas

# %%
#solução
lista = [['Brasil', 'Italia', [10, 9]], ['Brasil', 'Espanha', [5, 7]], ['Italia', 'Espanha', [7,8]]]

faltas_jogo = [x[2] for x in lista]
print('Faltas por jogo: ', faltas_jogo)

total_faltas_jogo = [x[0]+x[1] for x in faltas_jogo]
print('Total faltas por jogo: ', total_faltas_jogo)

total_faltas = sum(total_faltas_jogo)
print('Total faltas campeonato: ', total_faltas)

#time que fez mais ou menos faltas

#times
time1_jogo = [x[0] for x in lista]
time2_jogo = [x[1] for x in lista]
print('\n',time1_jogo,'-', time2_jogo)

#faltas
faltas_time1 = [x[0] for x in faltas_jogo]
faltas_time2 = [x[1] for x in faltas_jogo]
print(faltas_time1,'-', faltas_time2)

tp_faltas_time1 = list(zip(time1_jogo, faltas_time1))
tp_faltas_time2 = list(zip(time2_jogo, faltas_time2))
#dct_faltas_time2 = dict(zip(time2_jogo, faltas_time2))
#dct_faltas_time1 = {k:v for k, v in zip(time1_jogo, faltas_time1)}

print('\n',tp_faltas_time1)
print(tp_faltas_time2)


mais_faltas = [max(x) for x in faltas_jogo]
print(mais_faltas)


'''for x, y in tp_faltas_time1, mais_faltas:
  
  if (x[1] == y[0]):
    time_mais_faltas = [].append(tp_faltas_time1[0])

print(time_mais_faltas)
  #[max(x[1]) for x in tp_faltas_time1]
'''

''' if (x == tp_faltas_time1[0][1]):
      nomes += list(tp_faltas_time1[0])

  if (x == tp_faltas_time2[0][1]):
    nomes2.append(tp_faltas_time2[0])'''   

nomes2 = []
for x in mais_faltas:
  
  if (x == tp_faltas_time2[0][1]):
    nomes2.add(tp_faltas_time2[0])

#nomes2 += tp_faltas_time2[0]

print(nomes2)


#for x in lista:
  #Mais_faltas = [max(x[2]) for x in lista]
  # errado Mais_faltas = [x for x in lista if max(x[2])]

#print(Mais_faltas)
# Out:
# Faltas por jogo:  [[10, 9], [5, 7], [7, 8]]
# Total faltas por jogo:  [19, 12, 15]
# Total faltas campeonato:  46
#
#  ['Brasil', 'Brasil', 'Italia'] - ['Italia', 'Espanha', 'Espanha']
# [10, 5, 7] - [9, 7, 8]
#
#  [('Brasil', 10), ('Brasil', 5), ('Italia', 7)]
# [('Italia', 9), ('Espanha', 7), ('Espanha', 8)]
# [10, 7, 8]
# []

# %% [markdown]
# #### 8 Escreva um programa que conta a quantidade de vogais em uma string e armazena tal quantidade em um dicionário, onde a chave é a vogal considerada.

# %%
#solução

# %% [markdown]
# #### 9 Considere os conjuntos A={1,2,4,5} e B={1,a,b}. Imprima a união de A e B, a interseção de A e B, a diferença de A e B e a diferença de B e A.

# %%
#solução

# %% [markdown]
# #### 10 Faça um programa que solicite a data de nascimento (dd/mm/aaaa) do usuário e imprima a data com o nome do mês por extenso.

# %%
#solução

# %% [markdown]
# #### 11 Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês, sabendo-se que são descontados 11% para o Imposto de Renda, 8% para o INSS e 5% para o sindicato, faça um programa que nos dê:
# - salário bruto.
# - quanto pagou ao INSS.
# - quanto pagou ao sindicato.
# - o salário líquido.
# - calcule os descontos e o salário líquido, conforme a tabela abaixo:
# <table>
# <tr><td>+</td><td>Salário Bruto</td><td>R\$</td><td>0.00</td></tr>
# <tr><td>-</td><td>IR (27,5%)</td><td>R\$</td><td>0.00</td></tr>
# <tr><td>-</td><td>INSS (11%)</td><td>R\$</td><td>0.00</td></tr>
# <tr><td>-</td><td>Sindicato ( 5%)</td><td>R\$</td><td>0.00</td></tr>
# <tr><td>=</td><td>Salário Liquido</td><td>R\$</td><td>0.00</td></tr>
# </table>
#
# Obs.: Salário Bruto - Descontos = Salário Líquido.
# Utilize formatação de strings para o relatório sair alinhadinho.

# %%
#solução

# %% [markdown]
# #### 12 Leet é uma forma de se escrever o alfabeto latino usando outros símbolos em lugar das letras, como números por exemplo. A própria palavra leet admite muitas variações, como l33t ou 1337. O uso do leet reflete uma subcultura relacionada ao mundo dos jogos de computador e internet, sendo muito usada para confundir os iniciantes e afirmar-se como parte de um grupo. Pesquise sobre as principais formas de traduzir as letras. Depois, faça um programa que peça uma texto e transforme-o para a grafia leet speak.
# Desafio: não use loops nem desvios condicionais.

# %%
#solução

# %% [markdown]
# #### 13 Crie um programa que recebe uma lista de números e:
# - retorne o maior elemento
# - retorne a soma dos elementos
# - retorne o número de ocorrências do primeiro elemento da lista
# - retorne a média dos elementos
# - retorne o valor mais próximo da média dos elementos

# %%
#solução

# %% [markdown]
# ##### 14 Uma pista de Kart permite 10 voltas para cada um de 6 corredores. Escreva um programa que leia todos os tempos em segundos e os guarde em um dicionário, onde a chave é o nome do corredor. Ao final diga de quem foi a melhor volta da prova e em que volta; e ainda a classificação final em ordem (1o o campeão). O campeão é o que tem a menor média de tempos.

# %%
#solução

# %% [markdown]
# ##### 15 *Blocos de ações.* Um bloco de ações é representado como um certo número de atributos, incluindo uma data de compra, um preço de compra, um número de ações e um símbolo de cotação. Podemos registrar essas informações em uma tupla para cada bloco de estoque e realizar várias operações simples nos blocos.
#
# Vamos sonhar que temos o seguinte portfólio.
#
# <table>
#     <tr><th>Data da Compra</th><th>Preço de Compra</th><th>Ações</th><th>Símbolo</th><th>Preço Atual</th></tr>
# <tr><td>26 Jan 2015</td><td> 43.50</td><td> 25</td><td> CAT</td><td> 92.45</td><tr>
# <tr><td>26 Jan 2015</td><td> 42.80</td><td> 50</td><td> DD</td><td> 51.19</td><tr>
# <tr><td>26 Jan 2015</td><td> 42.10</td><td> 75</td><td> EK</td><td> 34.87</td><tr>
# <tr><td>26 Jan 2015</td><td> 37.58</td><td> 100</td><td> GM</td><td> 37.58</td><tr>
# </table>
# Podemos representar cada bloco de ações como uma tupla de cinco com data de compra, preço de compra, ações, símbolo e preço atual.
#
# `portfolio = [
# ("26-Jan-2015", 43.50, 25, 'CAT', 92.45),
# ("26-Jan-2015", 42.80, 50, 'DD', 51.19),
# ("26-Jan-2015", 42.10, 75, 'EK', 34.87),
# ("26-Jan-2015", 37.58, 100, 'GM', 37.58)
# ]`
#
# Desenvolva um programa que examine cada bloco, multiplique ações pelo preço de compra e determine o preço total de compra do portfólio. E, depois, examine cada bloco, multiplique ações pelo preço de compra e ações pelo preço atual para determinar o valor total ganho ou perdido.

# %%
#solução
